# %% [markdown]
# # Sales Data Analysis for a Supermarket
# Analyzing trends, customer behavior, and product sales from supermarket transactions.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('../data/supermarket_sales.csv')
df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.to_period('M')
df.head()
# Out:
#   Invoice ID Branch       City Customer Type  Gender            Product line  \
# 0  INV-00000      C   Mandalay        Member  Female       Health and beauty
# 1  INV-00001      A   Mandalay        Member    Male  Electronic accessories
# 2  INV-00002      C  Naypyitaw        Member  Female       Sports and travel
# 3  INV-00003      C   Mandalay        Member  Female      Food and beverages
# 4  INV-00004      A     Yangon        Normal    Male      Home and lifestyle
#
#    Unit price  Quantity  Tax 5%   Total       Date      Payment  Rating  \
# 0       87.70         6   26.31  552.51 2022-07-15  Credit card     4.4
# 1       56.72         7   19.85  416.89 2022-10-01  Credit card     5.2
# 2       53.13         3    7.97  167.36 2022-07-20      Ewallet     6.3
# 3       12.31         7    4.31   90.48 2023-01-04         Cash     9.9
# 4       40.71         8   16.28  341.96 2022-10-12      Ewallet     8.7
#
#      Month
# 0  2022-07
# 1  2022-10
# 2  2022-07
# 3  2023-01
# ...

# %% [markdown]
# # Monthly Sales

# %%
monthly_sales = df.groupby('Month')['Total'].sum()

monthly_sales.plot(kind='bar', color='skyblue', figsize=(10,5), title='Monthly Sales')
plt.ylabel('Revenue')
plt.savefig('bar_plot.png', bbox_inches = "tight")
plt.show()

# %% [markdown]
# # Product Line Revenue

# %%
product_revenue = df.groupby('Product line')['Total'].sum().sort_values(ascending=False)
sns.barplot(x=product_revenue.values, y=product_revenue.index, palette='viridis')
plt.title('Revenue by Product Line')
plt.xlabel('Total Revenue')
plt.savefig('bar.png', bbox_inches = "tight")
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2860\1065396474.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=product_revenue.values, y=product_revenue.index, palette='viridis')

# %% [markdown]
# # Gender-Based Revenue

# %%
gender_sales = df.groupby('Gender')['Total'].sum()
gender_sales.plot(kind='pie', autopct='%1.1f%%', startangle=90, title='Revenue by Gender')
plt.ylabel('')
plt.savefig('pie.png', bbox_inches = "tight")
plt.show()
